# %% [markdown]
# # 유럽 축구선수 분석
#
# ### Manchester United에는 어떤 선수를 영입해야할까?

# %% [markdown]
# # Introduction
#
# 2013년 5월 8일 Manchester United의 감독이자 유럽 축구의 한 획을 그은 Alex Ferguson감독이 은퇴를 하였다. Manchester United는 Alex Ferguson감독이 은퇴를 하고 당시 타팀에서 감독을 하던 데이비드 모이스감독을 선임 하였지만 거짓말처럼 하락세를 타며 팀의 명성에 걸맞지 않은 순위로 시즌을 끝냈다. 그 후 데이비드 모이스감독이 나간 후 루이 반 할, 조세 무리뉴등 세계적인 감독이 Manchester United의 지휘봉을 맡았으나 Manchester United는 Alex Ferguson감독이 지휘했던 시절의 위상을 되찾지 못했다. 이러한 사건들을 겪은 Manchester United는 Alex Ferguson감독이 지휘를 했던 당시 선수였던 올레 군나르 솔샤르 감독을 부임시키는 특단의 조취를 내놓았고, 2020년 3월 기준 올레 군나르 솔샤르감독은 2019/2020시즌 겨울시장에서 단 두명의 선수를 영입하며 Manchester United의 분위기를 반전시키는데 성공한다.
#
# 그렇다면, Manchester United의 분위기를 반전시킨 단 두명의 선수는 어떤 선수일까, 그 두명의 선수가 있었기에 Manchester United가 반전에 성공한 것일까?
#
# 문제가 해결되기 전인 2018/2019 FIFA데이터를 통해 Manchester United팀을 분석하고 해외 유럽 축구선수 중에 Manchester United에 필요한 유형인 선수를 발굴하고 현재 올레 군나르 솔샤르 감독이 영입한 선수와 비교해보자.

# %% [markdown]
# ---------------------------------------------------------------------------------------------------------------------------------
#
# # 1. 데이터 수집

# %% [markdown]
# ## a. 데이터 불러오기

# %%
import pandas as pd

# %%
# Fifa data 불러오기
data = pd.read_csv('/content/drive/My Drive/Colab Notebooks/data/FIFA_data.csv')

# %%
# 데이터 확인
data.head()
# Out:
#        ID               Name  Age  ... GKPositioning  GKReflexes  Release Clause
# 0  158023           L. Messi   31  ...          14.0         8.0         €226.5M
# 1   20801  Cristiano Ronaldo   33  ...          14.0        11.0         €127.1M
# 2  190871          Neymar Jr   26  ...          15.0        11.0         €228.1M
# 3  193080             De Gea   27  ...          88.0        94.0         €138.6M
# 4  192985       K. De Bruyne   27  ...          10.0        13.0         €196.4M
#
# [5 rows x 80 columns]

# %% [markdown]
# ## b. 데이터 확인 후, 분석 계획 설립
#
# ---

# %% [markdown]
# | 컬럼 명 |  컬럼 의미 |
# |--------|-----------|
# | ID | 고유의 번호 |
# | Name | 이름 |
# | Age | 나이 |
# | Overall | 현재 능력치 |
# | Potential | 잠재 능력치 |
# | Club | 소속 팀 |
# | Value | 예상 이적료 (유로) |
# | Wage | 주급 (유로)|
# | Preferred Foot | 잘 사용하는 발 |
# | Weak Foot | 잘 사용하지 않는 발 |
# | Skill Moves | 개인기 |
# | Position | 포지션 |
# | Jersey Number | 등번호 |
# | Joined | 소속 팀 입단 날짜 |
# | Contract Valid Until | 계약 기간 |
# | Height | 키 (피트) |
# | Weight | 몸무게 (파운드) |
# | LS ~ RB | 포지션 별 능력치 |
# | Crossing ~ GKReflexes | 세부 능력치 |
# | Release Clause | 바이아웃 |

# %% [markdown]
# #### 분석 순서
# - 1. Manchester United의 선수들을 분석
# - 2. Manchester United의 지역 라이벌  Manchester City선수와 능력치 비교
# - 3. 부족한 포지션 2개 선택
# - 4. 다른팀의 선수 중  Manchester United의 재정, 현실가능성, 영입방침을 고려하여 2명의 선수를 영입

# %% [markdown]
# --------------------------------------------------------------------------------------------------------------------------
# # 2. Manchester United 분석 - Manchester United는 어떤 선수들이 존재하는가?
# ## a. EDA

# %%
# 맨유 선수들만 추출
mu = data[data['Club'] == 'Manchester United']

# %%
# 맨유데이터 확인
mu.head()
# Out:
#          ID        Name  Age  ... GKPositioning  GKReflexes  Release Clause
# 3    193080      De Gea   27  ...          88.0        94.0         €138.6M
# 45   195864    P. Pogba   25  ...           4.0         3.0         €123.2M
# 47   192505   R. Lukaku   25  ...           7.0        10.0         €120.3M
# 93   184941  A. Sánchez   29  ...          12.0        13.0          €69.4M
# 116  211300  A. Martial   22  ...          15.0        11.0          €87.1M
#
# [5 rows x 80 columns]

# %%
# Club이 맨유인 선수들만 추출 된것 확인
mu['Club'].unique()
# Out:
# array(['Manchester United'], dtype=object)

# %%
# 맨유선수의 나이, 포지션, 능력치, 잠재 능력치 확인
print(f"맨유선수들의 평균 나이 : {mu['Age'].mean()}\n")
print(f"맨유선수들의 포지션 : {mu['Position'].unique()}\n")
print(f"맨유선수들의 평균 능력치 : {mu['Overall'].mean()}\n")
print(f"맨유선수들의 평균 잠재능력치 : {mu['Potential'].mean()}\n")
# Out:
# 맨유선수들의 평균 나이 : 24.757575757575758
#
# 맨유선수들의 포지션 : ['GK' 'RDM' 'ST' 'RW' 'LW' 'CDM' 'RM' 'CM' 'CAM' 'CB' 'RCB' 'LB' 'RB']
#
# 맨유선수들의 평균 능력치 : 80.18181818181819
#
# 맨유선수들의 평균 잠재능력치 : 82.81818181818181

# %%
import seaborn as sns
# Out:
# /usr/local/lib/python3.6/dist-packages/statsmodels/tools/_testing.py:19: FutureWarning: pandas.util.testing is deprecated. Use the functions in the public API at pandas.testing instead.
#   import pandas.util.testing as tm

# %%
# 나이별 선수 수
sns.countplot(mu['Age'])

# %%
# 포지션 별 선수 수
sns.countplot(mu['Position'])

# %%
# 포지션별 현재 능력치에 대한 Box Plot
sns.boxplot(x = mu['Position'], y = mu['Overall'])

# %% [markdown]
# ### CB에 두개의 이상치가 있는 것으로 확인되나 140이상의 이상치만 이상치일 것으로 예상

# %%
# 포지션별 잠재 능력치에 대한 Box Plot
sns.boxplot(x = mu['Position'], y = mu['Potential'])

# %% [markdown]
# ### 이상치 처리

# %%
# 이상치 확인
mu[(mu['Position'] == 'CB') & (mu['Overall'] > 100)]
# Out:
#            ID         Name  Age  ... GKPositioning  GKReflexes  Release Clause
# 11422  237160  R. Williams   19  ...           6.0         9.0           €2.2M
#
# [1 rows x 80 columns]

# %%
# 같은 포지션 선수의 Overall 과 CB점수의 비교
mu[mu['Position'] == 'CB'][['Name','Overall', 'Position', 'CB']]
# Out:
#               Name  Overall Position    CB
# 327      E. Bailly     81.0       CB  80+2
# 584    V. Lindelöf     79.0       CB  77+2
# 629        M. Rojo     79.0       CB  78+3
# 654       P. Jones     79.0       CB  78+2
# 11081     R. Poole     75.0       CB  62+2
# 11422  R. Williams    150.0       CB  62+2

# %%
# CB점수가 같으면 Overall 점수가 비슷함으로 동일한 CB점수를 가진 선수와 같은 Overall로 대체

mu['Overall'][11422] = 75
# Out:
# /usr/local/lib/python3.6/dist-packages/ipykernel_launcher.py:3: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   This is separate from the ipykernel package so we can avoid doing imports until
# /usr/local/lib/python3.6/dist-packages/IPython/core/interactiveshell.py:2882: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   exec(code_obj, self.user_global_ns, self.user_ns)

# %%
sns.boxplot(x=mu['Position'], y = mu['Overall'])

# %% [markdown]
# ### 결측치 찾기

# %%
mu.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# Int64Index: 33 entries, 3 to 12545
# Data columns (total 80 columns):
#  #   Column                    Non-Null Count  Dtype
# ---  ------                    --------------  -----
#  0   ID                        33 non-null     int64
#  1   Name                      33 non-null     object
#  2   Age                       33 non-null     int64
#  3   Nationality               33 non-null     object
#  4   Overall                   33 non-null     float64
#  5   Potential                 33 non-null     float64
#  6   Club                      33 non-null     object
#  7   Value                     33 non-null     object
#  8   Wage                      33 non-null     object
#  9   Preferred Foot            33 non-null     object
#  10  International Reputation  33 non-null     float64
#  11  Weak Foot                 33 non-null     float64
#  12  Skill Moves               33 non-null     float64
#  13  Position                  33 non-null     object
#  14  Jersey Number             33 non-null     float64
#  15  Joined                    33 non-null     object
#  16  Contract Valid Until      33 non-null     object
#  17  Height                    33 non-null     object
#  18  Weight                    33 non-null     object
#  19  LS                        30 non-null     object
#  20  ST                        30 non-null     object
#  21  RS                        30 non-null     object
#  22  LW                        30 non-null     object
#  23  LF                        30 non-null     object
#  24  CF                        30 non-null     object
#  25  RF                        30 non-null     object
#  26  RW                        30 non-null     object
#  27  LAM                       30 non-null     object
#  28  CAM                       30 non-null     object
#  29  RAM                       30 non-null     object
#  30  LM                        30 non-null     object
#  31  LCM                       30 non-null     object
#  32  CM                        30 non-null     object
#  33  RCM                       30 non-null     object
#  34  RM                        30 non-null     object
#  35  LWB                       30 non-null     object
#  36  LDM                       30 non-null     object
#  37  CDM                       30 non-null     object
#  38  RDM                       30 non-null     object
#  39  RWB                       30 non-null     object
#  40  LB                        30 non-null     object
#  41  LCB                       30 non-null     object
#  42  CB                        30 non-null     object
#  43  RCB                       30 non-null     object
#  44  RB                        30 non-null     object
#  45  Crossing                  33 non-null     float64
#  46  Finishing                 33 non-null     float64
#  47  HeadingAccuracy           33 non-null     float64
#  48  ShortPassing              33 non-null     float64
#  49  Volleys                   33 non-null     float64
#  50  Dribbling                 33 non-null     float64
#  51  Curve                     33 non-null     float64
#  52  FKAccuracy                33 non-null     float64
#  53  LongPassing               33 non-null     float64
#  54  BallControl               33 non-null     float64
#  55  Acceleration              33 non-null     float64
#  56  SprintSpeed               33 non-null     float64
#  57  Agility                   33 non-null     float64
#  58  Reactions                 33 non-null     float64
#  59  Balance                   33 non-null     float64
#  60  ShotPower                 33 non-null     float64
#  61  Jumping                   33 non-null     float64
#  62  Stamina                   33 non-null     float64
#  63  Strength                  33 non-null     float64
#  64  LongShots                 33 non-null     float64
#  65  Aggression                33 non-null     float64
#  66  Interceptions             33 non-null     float64
#  67  Positioning               33 non-null     float64
#  68  Vision                    33 non-null     float64
#  69  Penalties                 33 non-null     float64
#  70  Composure                 33 non-null     float64
#  71  Marking                   33 non-null     float64
#  72  StandingTackle            33 non-null     float64
#  73  SlidingTackle             33 non-null     float64
#  74  GKDiving                  33 non-null     float64
#  75  GKHandling                33 non-null     float64
#  76  GKKicking                 33 non-null     float64
#  77  GKPositioning             33 non-null     float64
#  78  GKReflexes                33 non-null     float64
#  79  Release Clause            33 non-null     object
# dtypes: float64(40), int64(2), object(38)
# memory usage: 22.1+ KB

# %%
# LS ~ RB 까지 결측치 3개 확인

mu[mu.isna()['LS']]


# GK  선수는 필드플레이어의 능력치가 결측치 처리 된 것을 확인
# Out:
#           ID       Name  Age  ... GKPositioning  GKReflexes  Release Clause
# 3     193080     De Gea   27  ...          88.0        94.0         €138.6M
# 526   173373  S. Romero   31  ...          77.0        82.0          €16.7M
# 2561   53739   L. Grant   35  ...          74.0        76.0           €2.5M
#
# [3 rows x 80 columns]

# %%
# NaN값을 측정할 수 없다는 의미의 -1로 교체
mu = mu.fillna(-1)

# %%
# 결칙치가 잘 대체되었는지 확인

mu.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# Int64Index: 33 entries, 3 to 12545
# Data columns (total 80 columns):
#  #   Column                    Non-Null Count  Dtype
# ---  ------                    --------------  -----
#  0   ID                        33 non-null     int64
#  1   Name                      33 non-null     object
#  2   Age                       33 non-null     int64
#  3   Nationality               33 non-null     object
#  4   Overall                   33 non-null     float64
#  5   Potential                 33 non-null     float64
#  6   Club                      33 non-null     object
#  7   Value                     33 non-null     object
#  8   Wage                      33 non-null     object
#  9   Preferred Foot            33 non-null     object
#  10  International Reputation  33 non-null     float64
#  11  Weak Foot                 33 non-null     float64
#  12  Skill Moves               33 non-null     float64
#  13  Position                  33 non-null     object
#  14  Jersey Number             33 non-null     float64
#  15  Joined                    33 non-null     object
#  16  Contract Valid Until      33 non-null     object
#  17  Height                    33 non-null     object
#  18  Weight                    33 non-null     object
#  19  LS                        33 non-null     object
#  20  ST                        33 non-null     object
#  21  RS                        33 non-null     object
#  22  LW                        33 non-null     object
#  23  LF                        33 non-null     object
#  24  CF                        33 non-null     object
#  25  RF                        33 non-null     object
#  26  RW                        33 non-null     object
#  27  LAM                       33 non-null     object
#  28  CAM                       33 non-null     object
#  29  RAM                       33 non-null     object
#  30  LM                        33 non-null     object
#  31  LCM                       33 non-null     object
#  32  CM                        33 non-null     object
#  33  RCM                       33 non-null     object
#  34  RM                        33 non-null     object
#  35  LWB                       33 non-null     object
#  36  LDM                       33 non-null     object
#  37  CDM                       33 non-null     object
#  38  RDM                       33 non-null     object
#  39  RWB                       33 non-null     object
#  40  LB                        33 non-null     object
#  41  LCB                       33 non-null     object
#  42  CB                        33 non-null     object
#  43  RCB                       33 non-null     object
#  44  RB                        33 non-null     object
#  45  Crossing                  33 non-null     float64
#  46  Finishing                 33 non-null     float64
#  47  HeadingAccuracy           33 non-null     float64
#  48  ShortPassing              33 non-null     float64
#  49  Volleys                   33 non-null     float64
#  50  Dribbling                 33 non-null     float64
#  51  Curve                     33 non-null     float64
#  52  FKAccuracy                33 non-null     float64
#  53  LongPassing               33 non-null     float64
#  54  BallControl               33 non-null     float64
#  55  Acceleration              33 non-null     float64
#  56  SprintSpeed               33 non-null     float64
#  57  Agility                   33 non-null     float64
#  58  Reactions                 33 non-null     float64
#  59  Balance                   33 non-null     float64
#  60  ShotPower                 33 non-null     float64
#  61  Jumping                   33 non-null     float64
#  62  Stamina                   33 non-null     float64
#  63  Strength                  33 non-null     float64
#  64  LongShots                 33 non-null     float64
#  65  Aggression                33 non-null     float64
#  66  Interceptions             33 non-null     float64
#  67  Positioning               33 non-null     float64
#  68  Vision                    33 non-null     float64
#  69  Penalties                 33 non-null     float64
#  70  Composure                 33 non-null     float64
#  71  Marking                   33 non-null     float64
#  72  StandingTackle            33 non-null     float64
#  73  SlidingTackle             33 non-null     float64
#  74  GKDiving                  33 non-null     float64
#  75  GKHandling                33 non-null     float64
#  76  GKKicking                 33 non-null     float64
#  77  GKPositioning             33 non-null     float64
#  78  GKReflexes                33 non-null     float64
#  79  Release Clause            33 non-null     object
# dtypes: float64(40), int64(2), object(38)
# memory usage: 22.1+ KB

# %% [markdown]
# # 3. Manchester United는 어떤 포지션을 보강해야 할까?
#
# ## a. 전처리

# %% [markdown]
# ### 맨유의 라이벌 맨시티와의 비교를 위한 전처리 진행

# %%
# Manchester City선수와 능력치 비교를 하기 위해 MU, MC선수가 담긴 데이터를 만듭니다.
df = data[(data['Club'] == 'Manchester United') | (data['Club'] == 'Manchester City')]

# %%
df.head()
# Out:
#         ID          Name  Age  ... GKPositioning  GKReflexes  Release Clause
# 3   193080        De Gea   27  ...          88.0        94.0         €138.6M
# 4   192985  K. De Bruyne   27  ...          10.0        13.0         €196.4M
# 13  168542   David Silva   32  ...           6.0        12.0           €111M
# 23  153079     S. Agüero   30  ...          11.0        14.0         €119.3M
# 45  195864      P. Pogba   25  ...           4.0         3.0         €123.2M
#
# [5 rows x 80 columns]

# %%
df = df.reset_index().drop(columns = 'index')

# %%
# 맨유와 맨시티선수들이 저장되었는 지 확인
df['Club'].unique()
# Out:
# array(['Manchester United', 'Manchester City'], dtype=object)

# %%
df.info()
# Value와 Wage가 object type인것을 확인
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 66 entries, 0 to 65
# Data columns (total 80 columns):
#  #   Column                    Non-Null Count  Dtype
# ---  ------                    --------------  -----
#  0   ID                        66 non-null     int64
#  1   Name                      66 non-null     object
#  2   Age                       66 non-null     int64
#  3   Nationality               66 non-null     object
#  4   Overall                   66 non-null     float64
#  5   Potential                 66 non-null     float64
#  6   Club                      66 non-null     object
#  7   Value                     66 non-null     object
#  8   Wage                      66 non-null     object
#  9   Preferred Foot            66 non-null     object
#  10  International Reputation  66 non-null     float64
#  11  Weak Foot                 66 non-null     float64
#  12  Skill Moves               66 non-null     float64
#  13  Position                  66 non-null     object
#  14  Jersey Number             66 non-null     float64
#  15  Joined                    66 non-null     object
#  16  Contract Valid Until      66 non-null     object
#  17  Height                    66 non-null     object
#  18  Weight                    66 non-null     object
#  19  LS                        59 non-null     object
#  20  ST                        59 non-null     object
#  21  RS                        59 non-null     object
#  22  LW                        59 non-null     object
#  23  LF                        59 non-null     object
#  24  CF                        59 non-null     object
#  25  RF                        59 non-null     object
#  26  RW                        59 non-null     object
#  27  LAM                       59 non-null     object
#  28  CAM                       59 non-null     object
#  29  RAM                       59 non-null     object
#  30  LM                        59 non-null     object
#  31  LCM                       59 non-null     object
#  32  CM                        59 non-null     object
#  33  RCM                       59 non-null     object
#  34  RM                        59 non-null     object
#  35  LWB                       59 non-null     object
#  36  LDM                       59 non-null     object
#  37  CDM                       59 non-null     object
#  38  RDM                       59 non-null     object
#  39  RWB                       59 non-null     object
#  40  LB                        59 non-null     object
#  41  LCB                       59 non-null     object
#  42  CB                        59 non-null     object
#  43  RCB                       59 non-null     object
#  44  RB                        59 non-null     object
#  45  Crossing                  66 non-null     float64
#  46  Finishing                 66 non-null     float64
#  47  HeadingAccuracy           66 non-null     float64
#  48  ShortPassing              66 non-null     float64
#  49  Volleys                   66 non-null     float64
#  50  Dribbling                 66 non-null     float64
#  51  Curve                     66 non-null     float64
#  52  FKAccuracy                66 non-null     float64
#  53  LongPassing               66 non-null     float64
#  54  BallControl               66 non-null     float64
#  55  Acceleration              66 non-null     float64
#  56  SprintSpeed               66 non-null     float64
#  57  Agility                   66 non-null     float64
#  58  Reactions                 66 non-null     float64
#  59  Balance                   66 non-null     float64
#  60  ShotPower                 66 non-null     float64
#  61  Jumping                   66 non-null     float64
#  62  Stamina                   66 non-null     float64
#  63  Strength                  66 non-null     float64
#  64  LongShots                 66 non-null     float64
#  65  Aggression                66 non-null     float64
#  66  Interceptions             66 non-null     float64
#  67  Positioning               66 non-null     float64
#  68  Vision                    66 non-null     float64
#  69  Penalties                 66 non-null     float64
#  70  Composure                 66 non-null     float64
#  71  Marking                   66 non-null     float64
#  72  StandingTackle            66 non-null     float64
#  73  SlidingTackle             66 non-null     float64
#  74  GKDiving                  66 non-null     float64
#  75  GKHandling                66 non-null     float64
#  76  GKKicking                 66 non-null     float64
#  77  GKPositioning             66 non-null     float64
#  78  GKReflexes                66 non-null     float64
#  79  Release Clause            66 non-null     object
# dtypes: float64(40), int64(2), object(38)
# memory usage: 41.4+ KB

# %% [markdown]
# ### 1M = 1,000,000
# ### 1K = 1,000

# %%
import warnings 
warnings.filterwarnings('ignore')

# %%
df['Value'] = df['Value'].str.slice(1,)

df['Value']
# Out:
# 0       72M
# 1      102M
# 2       60M
# 3     64.5M
# 4       64M
#       ...
# 61     525K
# 62     450K
# 63     400K
# 64     210K
# 65     120K
# Name: Value, Length: 66, dtype: object

# %%
s = '.'
for i in range(len(df)):
  if s in df['Value'][i]:
    df['Value'][i] = df['Value'][i].replace('.','')
    df['Value'][i] = df['Value'][i].replace('M','00000')
    df['Value'][i] = df['Value'][i].replace('K','00')
  else:
    df['Value'][i] = df['Value'][i].replace('M','000000')
    df['Value'][i] = df['Value'][i].replace('K','000')

# %%
df['Value']
# Out:
# 0      72000000
# 1     102000000
# 2      60000000
# 3      64500000
# 4      64000000
#         ...
# 61       525000
# 62       450000
# 63       400000
# 64       210000
# 65       120000
# Name: Value, Length: 66, dtype: object

# %%
df['Value'] = df['Value'].astype(int)

# %%
df.head()
# Out:
#        ID          Name  Age  ... GKPositioning  GKReflexes  Release Clause
# 0  193080        De Gea   27  ...          88.0        94.0         €138.6M
# 1  192985  K. De Bruyne   27  ...          10.0        13.0         €196.4M
# 2  168542   David Silva   32  ...           6.0        12.0           €111M
# 3  153079     S. Agüero   30  ...          11.0        14.0         €119.3M
# 4  195864      P. Pogba   25  ...           4.0         3.0         €123.2M
#
# [5 rows x 80 columns]

# %%
# MU선수들과 MC선수들을 분리
mu = df[df['Club'] == 'Manchester United']
mc = df[df['Club'] == 'Manchester City']

# %%
mu['Club'].unique()
# Out:
# array(['Manchester United'], dtype=object)

# %%
mu.head()
# Out:
#         ID        Name  Age  ... GKPositioning  GKReflexes  Release Clause
# 0   193080      De Gea   27  ...          88.0        94.0         €138.6M
# 4   195864    P. Pogba   25  ...           4.0         3.0         €123.2M
# 5   192505   R. Lukaku   25  ...           7.0        10.0         €120.3M
# 13  184941  A. Sánchez   29  ...          12.0        13.0          €69.4M
# 16  211300  A. Martial   22  ...          15.0        11.0          €87.1M
#
# [5 rows x 80 columns]

# %% [markdown]
# ### 주전선수 비교를 위하여 MU주전과 MC주전을 선발
#
# - GK : 1명, CB : 4명 MF : 4명 ST : 2명을 선발
# - 선발의 기준은 현재능력치
# - GK 리스트 = GK
# - CB 리스트 = CB, LCB, RCB, RB, LB
# - MF 리스트 = RCM, LCM, RDM, CDM, CM, RM, CAM
# - ST 리스트 = ST, LW, RW

# %%
# 각 포지션 별 리스트 작성
GK_list = ['GK']
CB_list = ['CB','LCB','RCB','RB','LB']
MF_list = ['RCM','LCM','RDM','CDM','CM','RM','CAM']
ST_list = ['ST','LW', 'RW']

# %%
# 주전 선수 선택

gk_count = 1
cb_count = 4
mf_count = 4
st_count = 2

mu_id = []
for index in mu.index:
  if mu['Position'][index] in GK_list:
    if gk_count != 0:
      gk_count -= 1
      mu_id.append(mu['ID'][index])
  elif mu['Position'][index] in CB_list:
    if cb_count != 0:
      mu['Position'][index] = 'CB'
      cb_count -= 1
      mu_id.append(mu['ID'][index])
  elif mu['Position'][index] in MF_list:
    if mf_count != 0:
      mu['Position'][index] = 'MF'
      mf_count -= 1
      mu_id.append(mu['ID'][index])
  else:
    if st_count != 0:
      mu['Position'][index] = 'ST'
      st_count -= 1
      mu_id.append(mu['ID'][index])

# %%
mu = mu[mu['ID'].isin(mu_id)]

# %%
 # 리스트 안에 있는 선수만 MC선수로 남긴다.
 # 주전 선수 선택

gk_count = 1
cb_count = 4
mf_count = 4
st_count = 2

mc_id = []
for index in mc.index:
  if mc['Position'][index] in GK_list:
    if gk_count != 0:
      gk_count -= 1
      mc_id.append(mc['ID'][index])
  elif mc['Position'][index] in CB_list:
    if cb_count != 0:
      mc['Position'][index] = 'CB'
      cb_count -= 1
      mc_id.append(mc['ID'][index])
  elif mc['Position'][index] in MF_list:
    if mf_count != 0:
      mc['Position'][index] = 'MF'
      mf_count -= 1
      mc_id.append(mc['ID'][index])
  else:
    if st_count != 0:
      mc['Position'][index] = 'ST'
      st_count -= 1
      mc_id.append(mc['ID'][index])

# %%
mc =mc[mc['ID'].isin(mc_id)]

# %%
 # mu, mc 주전선수가 모인 데이터를 만든다.

 df = pd.concat([mu,mc])

# %%
df
# Out:
#         ID          Name  Age  ... GKPositioning  GKReflexes  Release Clause
# 0   193080        De Gea   27  ...          88.0        94.0         €138.6M
# 4   195864      P. Pogba   25  ...           4.0         3.0         €123.2M
# 5   192505     R. Lukaku   25  ...           7.0        10.0         €120.3M
# 13  184941    A. Sánchez   29  ...          12.0        13.0          €69.4M
# 17  191202      N. Matić   29  ...          14.0         9.0          €44.4M
# 22  178088     Juan Mata   30  ...           5.0         8.0          €45.3M
# 23  209297          Fred   25  ...          11.0        15.0            €51M
# 26  225508     E. Bailly   24  ...           9.0         8.0          €43.1M
# 29  189881   C. Smalling   28  ...          15.0        15.0          €30.8M
# 31  205988       L. Shaw   22  ...           7.0         7.0          €31.8M
# 34  221660   V. Lindelöf   23  ...           7.0         9.0          €29.7M
# 1   192985  K. De Bruyne   27  ...          10.0        13.0         €196.4M
# 2   168542   David Silva   32  ...           6.0        12.0           €111M
# 3   153079     S. Agüero   30  ...          11.0        14.0         €119.3M
# 6   222492       L. Sané   22  ...           9.0        14.0         €125.1M
# 8   210257       Ederson   24  ...          82.0        87.0          €79.9M
# 10  135507   Fernandinho   33  ...          13.0         7.0          €33.3M
# 12  192366   N. Otamendi   30  ...          11.0        12.0          €52.7M
# 14  139720    V. Kompany   32  ...           8.0         6.0          €40.7M
# 15  212218    A. Laporte   24  ...          14.0         5.0          €65.5M
# 18  188377     K. Walker   28  ...          15.0         8.0          €45.3M
# 19  186942   I. Gündoğan   27  ...           5.0        13.0          €59.2M
#
# [22 rows x 80 columns]

# %% [markdown]
# ## b. EDA
#
# - 주전선수 비교

# %%
sns.boxplot(data = df , x='Position', y='Overall', hue = 'Club')

# %%
sns.boxplot(data=df,x='Position',y='Value', hue='Club')

# %% [markdown]
# MU선수와 MC선수를 비교해보면 가치에 맞는 Overall을 보여주는 형태이지만 맨유는 미드필드와 수비의 교체가 필요해보인다.

# %% [markdown]
# # 4. Manchester United는 어떤 선수를 영입해야 할까?
#
# ## a. EDA
#
# - 필요 포지션의 어떤 선수를 대체해야할지 확인
# - 기준은 영입일, 능력치, 잠재력, 나이
#
# ### 나이가 어릴 수록 잘할 가능성이 높고, 잠재력과 Overall이 높을 수록 잔류 점수를 높게 준다 현재 실력을 잠재력보다 더 높은 가중치를 준다.
#
# - 잔류포인트 = (Overall * 2 + Potential) / Age

# %%
mu['Point'] = (mu['Overall']*2 + mu['Potential']) / mu['Age']

# %%
mu[mu['Position'] == 'MF'][['Name','Age','Overall','Potential','Point']]
# Out:
#          Name  Age  Overall  Potential      Point
# 4    P. Pogba   25     87.0       91.0  10.600000
# 17   N. Matić   29     84.0       84.0   8.689655
# 22  Juan Mata   30     83.0       83.0   8.300000
# 23       Fred   25     82.0       84.0   9.920000

# %%
mu[mu['Position'] == 'CB'][['Name','Age','Overall','Potential','Point']]
# Out:
#            Name  Age  Overall  Potential      Point
# 26    E. Bailly   24     81.0       87.0  10.375000
# 29  C. Smalling   28     81.0       82.0   8.714286
# 31      L. Shaw   22     80.0       85.0  11.136364
# 34  V. Lindelöf   23     79.0       85.0  10.565217

# %% [markdown]
# #### 잔류포인트가 가장 낮은 Juan Mata, C. Smalling 방출 후 MF, CB한명씩 영입

# %% [markdown]
# ## b. 시각화
#
# 지금까지의 EDA를 바탕으로 데려올 선수들의 능력치를 시각화합시다.
#
# - Manchester United의 영입방칙은 최근 새로 부임한 솔샤르감독의 영입방침을 따릅니다.
# - 선수의 나이는 어릴수록 좋음
# - 잠재력 보다 현재 바로 주전으로 사용할 수 있는 선수
# - 포지션은 마타와 스몰링의 상세포지션인 RM, CB를 따른다.

# %%
# RM, CB 포지션을 제외한 선수들을 제거
market = data[(data['Position']=='RM') | (data['Position']=='CB')]

market
# Out:
#            ID            Name  Age  ... GKPositioning  GKReflexes  Release Clause
# 12     182493        D. Godín   32  ...           5.0        15.0          €90.2M
# 25     231747       K. Mbappé   19  ...          11.0         6.0         €166.1M
# 26     209331        M. Salah   26  ...          11.0        14.0         €137.3M
# 42     205600       S. Umtiti   24  ...          12.0        15.0         €121.1M
# 73     177509      M. Benatia   31  ...           7.0        11.0          €49.5M
# ...       ...             ...  ...  ...           ...         ...             ...
# 18133  246142  M. Finne Wørts   19  ...           6.0         7.0            €73K
# 18165  245412       H. Norris   17  ...           7.0        11.0           €119K
# 18168  245417       J. Manley   19  ...          13.0         5.0            €70K
# 18176  246227      T. Hillman   17  ...          10.0         8.0            €78K
# 18179  246243     J. Williams   17  ...          11.0         8.0           €119K
#
# [2902 rows x 80 columns]

# %%
sns.boxplot(data = market, x='Position', y='Overall')

# %% [markdown]
# Market 데이터에도 Overall 이 100이상인 이상치가 있는 것을 확인할 수 있다.
#
# 2902명의 선수들이 있으므로 이상치의 선수 데이터는 제거하고 진행

# %%
market[market['Overall']>100].index
# Out:
# Int64Index([11422], dtype='int64')

# %%
market = market.drop(11422)

# %% [markdown]
# ## 분류된 선수를 새로운 기준으로 순위를 매김
#
# *   (Overall * 2 + Potential) -  Age

# %%
market['Point'] = (market['Overall'] * 2 + market['Potential']) - market['Age']

market.head()
# Out:
#         ID        Name  Age  ... GKReflexes  Release Clause  Point
# 12  182493    D. Godín   32  ...       15.0          €90.2M  238.0
# 25  231747   K. Mbappé   19  ...        6.0         €166.1M  252.0
# 26  209331    M. Salah   26  ...       14.0         €137.3M  239.0
# 42  205600   S. Umtiti   24  ...       15.0         €121.1M  242.0
# 73  177509  M. Benatia   31  ...       11.0          €49.5M  227.0
#
# [5 rows x 81 columns]

# %%
market_cb = market[market['Position'] == 'CB']
market_rm = market[market['Position'] == 'RM']

# %%
market_cb = market_cb.sort_values(by='Point', ascending=False)
market_rm = market_rm.sort_values(by='Point', ascending=False)

# %%
market_cb.head()
# Out:
#          ID             Name  Age  ... GKReflexes  Release Clause  Point
# 25   231747        K. Mbappé   19  ...        6.0         €166.1M  252.0
# 26   209331         M. Salah   26  ...       14.0         €137.3M  239.0
# 122  204970       F. Thauvin   25  ...        9.0            €77M  230.0
# 233  227055   Gelson Martins   23  ...        9.0          €62.7M  228.0
# 243  212404  F. Bernardeschi   24  ...       12.0          €50.9M  227.0
#
# [5 rows x 81 columns]

# %%
market_rm.head()
# Out:
#          ID             Name  Age  ... GKReflexes  Release Clause  Point
# 25   231747        K. Mbappé   19  ...        6.0         €166.1M  252.0
# 26   209331         M. Salah   26  ...       14.0         €137.3M  239.0
# 122  204970       F. Thauvin   25  ...        9.0            €77M  230.0
# 233  227055   Gelson Martins   23  ...        9.0          €62.7M  228.0
# 243  212404  F. Bernardeschi   24  ...       12.0          €50.9M  227.0
#
# [5 rows x 81 columns]

# %%
import matplotlib.pyplot as plt

f, ax = plt.subplots(2,4,figsize=(30, 10))

vs_list = [ 'Age', 'Overall', 'Potential', 'Weak Foot']

for i in range(8):
  if i < 4 :
        colors = ['firebrick' if x > market_cb[:13][vs_list[i]].mean() else 'gray' for x in market_cb[:13][vs_list[i]]]
        
        sns.barplot(x= vs_list[i], y = 'Name', data = market_cb[:13], palette = colors, ax = ax[i//4, i%4])
        
        ax[i//4, i%4].axvline(market_cb[:13][vs_list[i]].mean(), ls = '--')
        
  else :
        sns.barplot(x = vs_list[i%4], y = 'Name', data = market_rm[:13], ax = ax[i//4, i%4])
        
        ax[i//4, i%4].axvline(market_rm[:13][vs_list[i%4]].mean(), ls= '--')

# %% [markdown]
# ### 나이는 어릴 수록 좋고 Overall과 Potential은 높을 수록 좋다는 기준으로 판단
#
# ### CB은 **S.Umtiti**, RM 은 **K.Mbappe** 가 가장 적합하다고 생각할 수 있다. 하지만 이적료나 몸값과 같은 부분을 고려한다면 또 다른 결과가 나올 수도 있다.
